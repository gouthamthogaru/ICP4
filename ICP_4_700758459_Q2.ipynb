# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")

# %%
(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
y_train = y_train.reshape(-1,)

# %%
# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)

# %%
# This code normalazation
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
from tensorflow.keras import layers, models

# Assuming you meant to use `models` instead of `keras.models` and similarly for `layers`.
lenet = models.Sequential([
    layers.Conv2D(6, kernel_size=5, strides=1, activation='relu', input_shape=(32,32,3), padding='same'), # C1
    layers.AveragePooling2D(pool_size=(2, 2)), # S2, fixed by adding pool_size
    layers.Conv2D(16, kernel_size=5, strides=1, activation='relu', padding='valid'), # C3
    layers.AveragePooling2D(pool_size=(2, 2)), # S4, fixed by adding pool_size
    layers.Conv2D(120, kernel_size=5, strides=1, activation='relu', padding='valid'), # C5
    layers.Flatten(), # Flatten
    layers.Dense(84, activation='relu'), # F6
    layers.Dense(10, activation='softmax') # Output layer
])

# %%
lenet.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 6)      │           456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 16, 16, 6)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 12, 12, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 6, 6, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 2, 2, 120)      │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 480)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 84)             │        40,404 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 92,246 (360.34 KB)
#  Trainable params: 92,246 (360.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
lenet.compile(optimizer='adam', loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])

# %%
hist = lenet.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test),verbose=1)
# Out:
# Epoch 1/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.3153 - loss: 1.8392 - val_accuracy: 0.4897 - val_loss: 1.4010
# Epoch 2/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5109 - loss: 1.3599 - val_accuracy: 0.5509 - val_loss: 1.2432
# Epoch 3/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5637 - loss: 1.2192 - val_accuracy: 0.5676 - val_loss: 1.2027
# Epoch 4/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5966 - loss: 1.1278 - val_accuracy: 0.6018 - val_loss: 1.1112
# Epoch 5/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6229 - loss: 1.0609 - val_accuracy: 0.6031 - val_loss: 1.1201
# Epoch 6/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6494 - loss: 0.9858 - val_accuracy: 0.6252 - val_loss: 1.0586
# Epoch 7/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6762 - loss: 0.9231 - val_accuracy: 0.6200 - val_loss: 1.0823
# Epoch 8/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6920 - loss: 0.8743 - val_accuracy: 0.6392 - val_loss: 1.0321
# Epoch 9/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7046 - loss: 0.8357 - val_accuracy: 0.6369 - val_loss: 1.0612
# Epoch 10/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7162 - loss: 0.7989 - val_accuracy: 0.6512 - val_loss: 1.0253
# Epoch 11/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7298 - loss: 0.7579 - val_accuracy: 0.6548 - val_loss: 1.0193
# Epoch 12/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7476 - loss: 0.7159 - val_accuracy: 0.6527 - val_loss: 1.0363
# Epoch 13/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7566 - loss: 0.6921 - val_accuracy: 0.6516 - val_loss: 1.0519
# Epoch 14/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7717 - loss: 0.6441 - val_accuracy: 0.6441 - val_loss: 1.0756
# Epoch 15/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7796 - loss: 0.6220 - val_accuracy: 0.6476 - val_loss: 1.1115
# Epoch 16/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7838 - loss: 0.6028 - val_accuracy: 0.6582 - val_loss: 1.0790
# Epoch 17/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7993 - loss: 0.5698 - val_accuracy: 0.6420 - val_loss: 1.1490
# Epoch 18/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8056 - loss: 0.5468 - val_accuracy: 0.6397 - val_loss: 1.1610
# Epoch 19/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8197 - loss: 0.5128 - val_accuracy: 0.6458 - val_loss: 1.2173
# Epoch 20/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8258 - loss: 0.4931 - val_accuracy: 0.6379 - val_loss: 1.2454
# Epoch 21/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8313 - loss: 0.4770 - val_accuracy: 0.6416 - val_loss: 1.2651
# Epoch 22/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8467 - loss: 0.4387 - val_accuracy: 0.6495 - val_loss: 1.2889
# Epoch 23/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8469 - loss: 0.4336 - val_accuracy: 0.6369 - val_loss: 1.3758
# Epoch 24/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8570 - loss: 0.4075 - val_accuracy: 0.6359 - val_loss: 1.3644
# Epoch 25/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8624 - loss: 0.3892 - val_accuracy: 0.6330 - val_loss: 1.4470
# Epoch 26/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8668 - loss: 0.3793 - val_accuracy: 0.6386 - val_loss: 1.5068
# Epoch 27/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8723 - loss: 0.3611 - val_accuracy: 0.6228 - val_loss: 1.5322
# Epoch 28/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8762 - loss: 0.3452 - val_accuracy: 0.6266 - val_loss: 1.5829
# Epoch 29/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8846 - loss: 0.3214 - val_accuracy: 0.6206 - val_loss: 1.7561
# Epoch 30/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8891 - loss: 0.3080 - val_accuracy: 0.6301 - val_loss: 1.7235
# Epoch 31/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8933 - loss: 0.2954 - val_accuracy: 0.6196 - val_loss: 1.7668
# Epoch 32/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8932 - loss: 0.2947 - val_accuracy: 0.6260 - val_loss: 1.8354
# Epoch 33/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8997 - loss: 0.2816 - val_accuracy: 0.6269 - val_loss: 1.8537
# Epoch 34/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9072 - loss: 0.2603 - val_accuracy: 0.6230 - val_loss: 1.8308
# Epoch 35/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9110 - loss: 0.2493 - val_accuracy: 0.6202 - val_loss: 2.0127
# Epoch 36/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9118 - loss: 0.2442 - val_accuracy: 0.6339 - val_loss: 2.0313
# Epoch 37/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9157 - loss: 0.2385 - val_accuracy: 0.6175 - val_loss: 2.1154
# Epoch 38/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9200 - loss: 0.2225 - val_accuracy: 0.6199 - val_loss: 2.1817
# Epoch 39/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9232 - loss: 0.2175 - val_accuracy: 0.6218 - val_loss: 2.2445
# Epoch 40/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9246 - loss: 0.2089 - val_accuracy: 0.6180 - val_loss: 2.3115
# Epoch 41/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9272 - loss: 0.2066 - val_accuracy: 0.6206 - val_loss: 2.2952
# Epoch 42/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9270 - loss: 0.2002 - val_accuracy: 0.6153 - val_loss: 2.4150
# Epoch 43/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9303 - loss: 0.1926 - val_accuracy: 0.6066 - val_loss: 2.4556
# Epoch 44/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9327 - loss: 0.1857 - val_accuracy: 0.6191 - val_loss: 2.5005
# Epoch 45/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9361 - loss: 0.1804 - val_accuracy: 0.6115 - val_loss: 2.6104
# Epoch 46/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9384 - loss: 0.1734 - val_accuracy: 0.6120 - val_loss: 2.6750
# Epoch 47/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9368 - loss: 0.1757 - val_accuracy: 0.6136 - val_loss: 2.6363
# Epoch 48/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9429 - loss: 0.1619 - val_accuracy: 0.6145 - val_loss: 2.7443
# Epoch 49/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9376 - loss: 0.1801 - val_accuracy: 0.6161 - val_loss: 2.6583
# Epoch 50/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9440 - loss: 0.1573 - val_accuracy: 0.6119 - val_loss: 2.8275
# Epoch 51/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9464 - loss: 0.1509 - val_accuracy: 0.6127 - val_loss: 2.9426
# Epoch 52/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9454 - loss: 0.1567 - val_accuracy: 0.6169 - val_loss: 2.8903
# Epoch 53/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9470 - loss: 0.1519 - val_accuracy: 0.6154 - val_loss: 2.9228
# Epoch 54/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9441 - loss: 0.1536 - val_accuracy: 0.6153 - val_loss: 2.9414
# Epoch 55/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9526 - loss: 0.1355 - val_accuracy: 0.6154 - val_loss: 2.9936
# Epoch 56/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9516 - loss: 0.1410 - val_accuracy: 0.6088 - val_loss: 3.1300
# Epoch 57/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9477 - loss: 0.1458 - val_accuracy: 0.6066 - val_loss: 3.0778
# Epoch 58/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9473 - loss: 0.1495 - val_accuracy: 0.6116 - val_loss: 3.1577
# Epoch 59/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9518 - loss: 0.1346 - val_accuracy: 0.6166 - val_loss: 3.2063
# Epoch 60/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9533 - loss: 0.1325 - val_accuracy: 0.6064 - val_loss: 3.3109
# Epoch 61/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9488 - loss: 0.1505 - val_accuracy: 0.6064 - val_loss: 3.2623
# Epoch 62/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9509 - loss: 0.1370 - val_accuracy: 0.6020 - val_loss: 3.4756
# Epoch 63/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9507 - loss: 0.1413 - val_accuracy: 0.6105 - val_loss: 3.4578
# Epoch 64/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9498 - loss: 0.1454 - val_accuracy: 0.6062 - val_loss: 3.3347
# Epoch 65/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9566 - loss: 0.1232 - val_accuracy: 0.6059 - val_loss: 3.5564
# Epoch 66/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9551 - loss: 0.1280 - val_accuracy: 0.6102 - val_loss: 3.5617
# Epoch 67/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9567 - loss: 0.1208 - val_accuracy: 0.6055 - val_loss: 3.5458
# Epoch 68/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9547 - loss: 0.1272 - val_accuracy: 0.6111 - val_loss: 3.6257
# Epoch 69/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9566 - loss: 0.1264 - val_accuracy: 0.6081 - val_loss: 3.6213
# Epoch 70/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9598 - loss: 0.1143 - val_accuracy: 0.6117 - val_loss: 3.5931
# Epoch 71/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9556 - loss: 0.1216 - val_accuracy: 0.6052 - val_loss: 3.6421
# Epoch 72/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9564 - loss: 0.1218 - val_accuracy: 0.6137 - val_loss: 3.6696
# Epoch 73/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9616 - loss: 0.1121 - val_accuracy: 0.6107 - val_loss: 3.7213
# Epoch 74/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9600 - loss: 0.1148 - val_accuracy: 0.6036 - val_loss: 3.6864
# Epoch 75/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9587 - loss: 0.1194 - val_accuracy: 0.6156 - val_loss: 3.7448
# Epoch 76/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9628 - loss: 0.1098 - val_accuracy: 0.6093 - val_loss: 3.6917
# Epoch 77/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9641 - loss: 0.1025 - val_accuracy: 0.6013 - val_loss: 3.9174
# Epoch 78/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9606 - loss: 0.1139 - val_accuracy: 0.6096 - val_loss: 3.9367
# Epoch 79/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9601 - loss: 0.1147 - val_accuracy: 0.6095 - val_loss: 3.8103
# Epoch 80/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9613 - loss: 0.1160 - val_accuracy: 0.6169 - val_loss: 3.9854
# Epoch 81/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9615 - loss: 0.1098 - val_accuracy: 0.6161 - val_loss: 4.0320
# Epoch 82/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9609 - loss: 0.1157 - val_accuracy: 0.6008 - val_loss: 3.9423
# Epoch 83/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9608 - loss: 0.1120 - val_accuracy: 0.6084 - val_loss: 3.9935
# Epoch 84/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9662 - loss: 0.0983 - val_accuracy: 0.6059 - val_loss: 4.0283
# Epoch 85/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9615 - loss: 0.1099 - val_accuracy: 0.6073 - val_loss: 4.0633
# Epoch 86/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9641 - loss: 0.1070 - val_accuracy: 0.6103 - val_loss: 3.9780
# Epoch 87/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9628 - loss: 0.1109 - val_accuracy: 0.6032 - val_loss: 4.1314
# Epoch 88/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9673 - loss: 0.0918 - val_accuracy: 0.6030 - val_loss: 4.0756
# Epoch 89/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9604 - loss: 0.1152 - val_accuracy: 0.5954 - val_loss: 4.3502
# Epoch 90/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9644 - loss: 0.1029 - val_accuracy: 0.6114 - val_loss: 4.1359
# Epoch 91/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9660 - loss: 0.0980 - val_accuracy: 0.6095 - val_loss: 4.0965
# Epoch 92/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9649 - loss: 0.1027 - val_accuracy: 0.6060 - val_loss: 4.3054
# Epoch 93/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9635 - loss: 0.1071 - val_accuracy: 0.6076 - val_loss: 4.1802
# Epoch 94/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9622 - loss: 0.1124 - val_accuracy: 0.6065 - val_loss: 4.3317
# Epoch 95/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9707 - loss: 0.0902 - val_accuracy: 0.6056 - val_loss: 4.4288
# Epoch 96/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9676 - loss: 0.0943 - val_accuracy: 0.6110 - val_loss: 4.2322
# Epoch 97/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9706 - loss: 0.0880 - val_accuracy: 0.6102 - val_loss: 4.3887
# Epoch 98/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9682 - loss: 0.0969 - val_accuracy: 0.6122 - val_loss: 4.3895
# Epoch 99/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9657 - loss: 0.1037 - val_accuracy: 0.6063 - val_loss: 4.2871
# Epoch 100/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9689 - loss: 0.0916 - val_accuracy: 0.6104 - val_loss: 4.5234

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title("Accuracy by LeNet on CIFAR-10 Data")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss by LeNet on CIFAR-10 Data')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
y_predictions= lenet.predict(x_test)
y_predictions.reshape(-1,)
y_predictions= np.argmax(y_predictions, axis=1)

confusion_matrix(y_test, y_predictions)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[682,  31,  73,  39,  35,  18,  16,  13,  56,  37],
#        [ 36, 744,  10,  18,  13,   8,  13,   7,  23, 128],
#        [ 72,  12, 485,  92, 109,  65,  82,  49,  15,  19],
#        [ 27,  19,  75, 431,  92, 171,  85,  47,  16,  37],
#        [ 30,   7,  94,  67, 571,  59,  66,  78,  16,  12],
#        [ 13,   7,  59, 214,  82, 484,  45,  69,  12,  15],
#        [ 10,  15,  58,  75,  77,  37, 684,  17,   6,  21],
#        [ 16,   8,  49,  64,  93,  65,  25, 653,   1,  26],
#        [112,  81,  21,  20,  19,  19,  15,   9, 656,  48],
#        [ 55, 117,  14,  19,   7,  17,  13,  25,  19, 714]])

# %%
# confusion matrix and accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix', fontsize=16)
plt.imshow(confusion_matrix(y_test, y_predictions))
plt.xticks(np.arange(10), classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), classes, fontsize=12)
plt.colorbar()
plt.show()

# %%
print("Test accuracy:", accuracy_score(y_test, y_predictions))
# Out:
# Test accuracy: 0.6104

# %%
L = 8
W = 8
fig, axes = plt.subplots(L, W, figsize = (20,20))
axes = axes.ravel() #

for i in np.arange(0, L * W):
    axes[i].imshow(x_test[i])
    axes[i].set_title("Predicted = {}\n Actual  = {}".format(classes[y_predictions[i]], classes[y_test[i]]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.optimizers import SGD, Adam

# %%
#Define Alexnet Model
AlexNet = Sequential()
AlexNet.add(Conv2D(filters=16,kernel_size=(3,3),strides=(4,4),input_shape=(32,32,3), activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Conv2D(60,(5,5),padding='same',activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Conv2D(60,(3,3),padding='same',activation='relu'))
AlexNet.add(Conv2D(30,(3,3),padding='same',activation='relu'))
AlexNet.add(Conv2D(20,(3,3),padding='same',activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Flatten())
AlexNet.add(Dense(200, activation='relu'))
AlexNet.add(Dropout(0.1))
AlexNet.add(Dense(200, activation='relu'))
AlexNet.add(Dropout(0.1))
AlexNet.add(Dense(10,activation='softmax'))

AlexNet.compile(optimizer='SGD', loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])
AlexNet.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 8, 8, 16)       │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 4, 4, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 4, 4, 60)       │        24,060 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 2, 2, 60)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 2, 2, 60)       │        32,460 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 2, 2, 30)       │        16,230 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 2, 2, 20)       │         5,420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 1, 1, 20)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 200)            │         4,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 200)            │        40,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 125,028 (488.39 KB)
#  Trainable params: 125,028 (488.39 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history1 = AlexNet.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test),verbose=1)
# Out:
# Epoch 1/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.1174 - loss: 2.3014 - val_accuracy: 0.1650 - val_loss: 2.2938
# Epoch 2/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.1619 - loss: 2.2774 - val_accuracy: 0.1743 - val_loss: 2.1983
# Epoch 3/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.2109 - loss: 2.0828 - val_accuracy: 0.2444 - val_loss: 1.9815
# Epoch 4/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.2583 - loss: 1.9421 - val_accuracy: 0.3118 - val_loss: 1.7918
# Epoch 5/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.2984 - loss: 1.8067 - val_accuracy: 0.2761 - val_loss: 2.0276
# Epoch 6/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3495 - loss: 1.7091 - val_accuracy: 0.3788 - val_loss: 1.6398
# Epoch 7/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3770 - loss: 1.6454 - val_accuracy: 0.4014 - val_loss: 1.6005
# Epoch 8/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4060 - loss: 1.5765 - val_accuracy: 0.3917 - val_loss: 1.6997
# Epoch 9/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4356 - loss: 1.5077 - val_accuracy: 0.4250 - val_loss: 1.5584
# Epoch 10/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4544 - loss: 1.4616 - val_accuracy: 0.4690 - val_loss: 1.4354
# Epoch 11/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4756 - loss: 1.4141 - val_accuracy: 0.4743 - val_loss: 1.4195
# Epoch 12/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4967 - loss: 1.3676 - val_accuracy: 0.4873 - val_loss: 1.3943
# Epoch 13/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5120 - loss: 1.3288 - val_accuracy: 0.4875 - val_loss: 1.3833
# Epoch 14/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5288 - loss: 1.2877 - val_accuracy: 0.5227 - val_loss: 1.3135
# Epoch 15/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5419 - loss: 1.2538 - val_accuracy: 0.5140 - val_loss: 1.3346
# Epoch 16/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5543 - loss: 1.2259 - val_accuracy: 0.5245 - val_loss: 1.3124
# Epoch 17/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5682 - loss: 1.1939 - val_accuracy: 0.5179 - val_loss: 1.3554
# Epoch 18/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5802 - loss: 1.1644 - val_accuracy: 0.5442 - val_loss: 1.2760
# Epoch 19/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5868 - loss: 1.1474 - val_accuracy: 0.5409 - val_loss: 1.2826
# Epoch 20/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5964 - loss: 1.1207 - val_accuracy: 0.5454 - val_loss: 1.2752
# Epoch 21/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5995 - loss: 1.1089 - val_accuracy: 0.5317 - val_loss: 1.3198
# Epoch 22/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6101 - loss: 1.0842 - val_accuracy: 0.5517 - val_loss: 1.2614
# Epoch 23/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6201 - loss: 1.0698 - val_accuracy: 0.5543 - val_loss: 1.2640
# Epoch 24/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6242 - loss: 1.0450 - val_accuracy: 0.5560 - val_loss: 1.2769
# Epoch 25/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6342 - loss: 1.0294 - val_accuracy: 0.5422 - val_loss: 1.3025
# Epoch 26/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6407 - loss: 1.0093 - val_accuracy: 0.5354 - val_loss: 1.3836
# Epoch 27/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6472 - loss: 1.0009 - val_accuracy: 0.5532 - val_loss: 1.2936
# Epoch 28/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6539 - loss: 0.9729 - val_accuracy: 0.5557 - val_loss: 1.2889
# Epoch 29/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6616 - loss: 0.9514 - val_accuracy: 0.5448 - val_loss: 1.3128
# Epoch 30/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6601 - loss: 0.9570 - val_accuracy: 0.5510 - val_loss: 1.3293
# Epoch 31/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6751 - loss: 0.9160 - val_accuracy: 0.5665 - val_loss: 1.2574
# Epoch 32/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6750 - loss: 0.9142 - val_accuracy: 0.5534 - val_loss: 1.3146
# Epoch 33/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6847 - loss: 0.9000 - val_accuracy: 0.5449 - val_loss: 1.3272
# Epoch 34/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6854 - loss: 0.8878 - val_accuracy: 0.5618 - val_loss: 1.2863
# Epoch 35/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6922 - loss: 0.8707 - val_accuracy: 0.5471 - val_loss: 1.3440
# Epoch 36/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7014 - loss: 0.8542 - val_accuracy: 0.5538 - val_loss: 1.3116
# Epoch 37/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7084 - loss: 0.8320 - val_accuracy: 0.5590 - val_loss: 1.3187
# Epoch 38/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7097 - loss: 0.8295 - val_accuracy: 0.5529 - val_loss: 1.3543
# Epoch 39/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7149 - loss: 0.8150 - val_accuracy: 0.5653 - val_loss: 1.3232
# Epoch 40/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7261 - loss: 0.7921 - val_accuracy: 0.5412 - val_loss: 1.3996
# Epoch 41/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7249 - loss: 0.7854 - val_accuracy: 0.5584 - val_loss: 1.3721
# Epoch 42/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7282 - loss: 0.7729 - val_accuracy: 0.5565 - val_loss: 1.3746
# Epoch 43/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7393 - loss: 0.7469 - val_accuracy: 0.5557 - val_loss: 1.3896
# Epoch 44/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7388 - loss: 0.7423 - val_accuracy: 0.5583 - val_loss: 1.3845
# Epoch 45/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7431 - loss: 0.7334 - val_accuracy: 0.5411 - val_loss: 1.5062
# Epoch 46/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7476 - loss: 0.7199 - val_accuracy: 0.5333 - val_loss: 1.5971
# Epoch 47/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7522 - loss: 0.7062 - val_accuracy: 0.5432 - val_loss: 1.4983
# Epoch 48/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7583 - loss: 0.6965 - val_accuracy: 0.5501 - val_loss: 1.4711
# Epoch 49/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7658 - loss: 0.6741 - val_accuracy: 0.5567 - val_loss: 1.4579
# Epoch 50/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7699 - loss: 0.6530 - val_accuracy: 0.5516 - val_loss: 1.4302
# Epoch 51/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7814 - loss: 0.6365 - val_accuracy: 0.5524 - val_loss: 1.4765
# Epoch 52/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7777 - loss: 0.6297 - val_accuracy: 0.5508 - val_loss: 1.4694
# Epoch 53/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7838 - loss: 0.6220 - val_accuracy: 0.5527 - val_loss: 1.5334
# Epoch 54/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7868 - loss: 0.6068 - val_accuracy: 0.5589 - val_loss: 1.5618
# Epoch 55/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7927 - loss: 0.5965 - val_accuracy: 0.5589 - val_loss: 1.5208
# Epoch 56/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7967 - loss: 0.5789 - val_accuracy: 0.5516 - val_loss: 1.5921
# Epoch 57/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7992 - loss: 0.5779 - val_accuracy: 0.5541 - val_loss: 1.6207
# Epoch 58/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8027 - loss: 0.5649 - val_accuracy: 0.5559 - val_loss: 1.5916
# Epoch 59/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8055 - loss: 0.5621 - val_accuracy: 0.5437 - val_loss: 1.6927
# Epoch 60/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8116 - loss: 0.5384 - val_accuracy: 0.5355 - val_loss: 1.7048
# Epoch 61/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8200 - loss: 0.5220 - val_accuracy: 0.5528 - val_loss: 1.6579
# Epoch 62/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8207 - loss: 0.5121 - val_accuracy: 0.5352 - val_loss: 1.7522
# Epoch 63/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8250 - loss: 0.5025 - val_accuracy: 0.5494 - val_loss: 1.6855
# Epoch 64/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8252 - loss: 0.4989 - val_accuracy: 0.5292 - val_loss: 1.8410
# Epoch 65/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8279 - loss: 0.4851 - val_accuracy: 0.5374 - val_loss: 1.8271
# Epoch 66/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8324 - loss: 0.4734 - val_accuracy: 0.5458 - val_loss: 1.7590
# Epoch 67/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8396 - loss: 0.4603 - val_accuracy: 0.5213 - val_loss: 1.8734
# Epoch 68/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8400 - loss: 0.4596 - val_accuracy: 0.5366 - val_loss: 1.9257
# Epoch 69/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8416 - loss: 0.4545 - val_accuracy: 0.5415 - val_loss: 1.8818
# Epoch 70/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8538 - loss: 0.4300 - val_accuracy: 0.5332 - val_loss: 1.8542
# Epoch 71/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8550 - loss: 0.4257 - val_accuracy: 0.5463 - val_loss: 1.8746
# Epoch 72/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8558 - loss: 0.4158 - val_accuracy: 0.5428 - val_loss: 1.8943
# Epoch 73/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8590 - loss: 0.4043 - val_accuracy: 0.5349 - val_loss: 1.9456
# Epoch 74/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8588 - loss: 0.4000 - val_accuracy: 0.5301 - val_loss: 2.0615
# Epoch 75/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8615 - loss: 0.3978 - val_accuracy: 0.5371 - val_loss: 2.0184
# Epoch 76/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8668 - loss: 0.3905 - val_accuracy: 0.5405 - val_loss: 2.0499
# Epoch 77/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8646 - loss: 0.3845 - val_accuracy: 0.5281 - val_loss: 2.0273
# Epoch 78/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8739 - loss: 0.3597 - val_accuracy: 0.5377 - val_loss: 1.9810
# Epoch 79/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8728 - loss: 0.3644 - val_accuracy: 0.5358 - val_loss: 2.1320
# Epoch 80/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8728 - loss: 0.3632 - val_accuracy: 0.5328 - val_loss: 2.1225
# Epoch 81/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8808 - loss: 0.3486 - val_accuracy: 0.5382 - val_loss: 2.0852
# Epoch 82/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8836 - loss: 0.3333 - val_accuracy: 0.4875 - val_loss: 2.6993
# Epoch 83/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8823 - loss: 0.3396 - val_accuracy: 0.5361 - val_loss: 2.1527
# Epoch 84/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8864 - loss: 0.3260 - val_accuracy: 0.5349 - val_loss: 2.2135
# Epoch 85/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8913 - loss: 0.3141 - val_accuracy: 0.5447 - val_loss: 2.2399
# Epoch 86/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8901 - loss: 0.3176 - val_accuracy: 0.5355 - val_loss: 2.1969
# Epoch 87/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8909 - loss: 0.3175 - val_accuracy: 0.5332 - val_loss: 2.2302
# Epoch 88/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8948 - loss: 0.3051 - val_accuracy: 0.5285 - val_loss: 2.2447
# Epoch 89/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8924 - loss: 0.3058 - val_accuracy: 0.5233 - val_loss: 2.4888
# Epoch 90/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8988 - loss: 0.2953 - val_accuracy: 0.5257 - val_loss: 2.3782
# Epoch 91/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9043 - loss: 0.2857 - val_accuracy: 0.5206 - val_loss: 2.4952
# Epoch 92/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9036 - loss: 0.2768 - val_accuracy: 0.5357 - val_loss: 2.3853
# Epoch 93/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9021 - loss: 0.2828 - val_accuracy: 0.5347 - val_loss: 2.4094
# Epoch 94/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9047 - loss: 0.2732 - val_accuracy: 0.5317 - val_loss: 2.4856
# Epoch 95/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9058 - loss: 0.2645 - val_accuracy: 0.5019 - val_loss: 3.0382
# Epoch 96/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9097 - loss: 0.2630 - val_accuracy: 0.5307 - val_loss: 2.4891
# Epoch 97/100
#  593/1563 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9211 - loss: 0.2323

# %%
# summarize history for accuracy
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title("Accuracy by AlexNet on CIFAR-10 Data")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Loss by AlexNet on CIFAR-10 Data')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
y_predictions1 = AlexNet.predict(x_test)
y_predictions1.reshape(-1,)
y_predictions1= np.argmax(y_predictions1, axis=1)

confusion_matrix(y_test, y_predictions1)

# %%
# confusion matrix and accuracy
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix of AlexNet Model', fontsize=16)
plt.imshow(confusion_matrix(y_test, y_predictions1))
plt.xticks(np.arange(10), classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), classes, fontsize=12)
plt.colorbar()
plt.show()

# %%
print("Test accuracy by AlexNet:", accuracy_score(y_test, y_predictions))

# %%
L = 8
W = 8
fig, axes = plt.subplots(L, W, figsize = (20,20))
axes = axes.ravel() #

for i in np.arange(0, L * W):
    axes[i].imshow(x_test[i])
    axes[i].set_title("Predicted = {}\n Actual  = {}".format(classes[y_predictions[i]], classes[y_test[i]]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
